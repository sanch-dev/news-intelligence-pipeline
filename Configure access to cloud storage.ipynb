# %%
# %fs ls 'abfss://news-intelligence-container@newsintelligencestgac.dfs.core.windows.net/'

# %% [markdown]
# ### Create external location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS newsintelligencestgac_newsintelligence
URL 'abfss://news-intelligence-container@newsintelligencestgac.dfs.core.windows.net/'
WITH ( STORAGE CREDENTIAL `news-intelligence-sc`)
COMMENT 'External location for news-intelligence container';
